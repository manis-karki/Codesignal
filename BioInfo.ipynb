# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB 
# I was having difficulty installing the conda so used the help of you tube video 
#https://youtu.be/Rm2ak31u1us
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
# !conda install -c bioconda sra-tools
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sra-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.26 |       h06a4308_2         115 KB
#     certifi-2021.10.8          |   py37h06a4308_2         151 KB
#     conda-4.11.0               |   py37h06a4308_0        14.4 MB
#     openssl-1.1.1m             |       h7f8727e_0         2.5 MB
#     sra-tools-2.8.0            |                0        99.7 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:       117.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   sra-tools          bioconda/linux-64::sra-tools-2.8.0-0
#
# The following packages will be UPDATED:
#
# ...

# %%
# !conda install -c bioconda megahit
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - megahit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     megahit-1.2.9              |       h8b12597_0         2.6 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   megahit            bioconda/linux-64::megahit-1.2.9-h8b12597_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# megahit-1.2.9        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
# done
# done
# done

# %%
# !wget https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR12616406/SRR12616406
# Out:
# --2022-01-29 20:48:42--  https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR12616406/SRR12616406
# Resolving sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)... 52.217.137.113
# Connecting to sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)|52.217.137.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1725941543 (1.6G) [binary/octet-stream]
# Saving to: ‘SRR12616406’
#
# SRR12616406         100%[===================>]   1.61G  16.2MB/s    in 1m 46s
#
# 2022-01-29 20:50:29 (15.6 MB/s) - ‘SRR12616406’ saved [1725941543/1725941543]

# %%
# !fastq-dump -F --split-files /content/SRR12616406
# Out:
# Read 16117526 spots for /content/SRR12616406
# Written 16117526 spots for /content/SRR12616406

# %%
# !megahit -1 SRR12616406_1.fastq -2 SRR12616406_2.fastq -o assemble --verbose
# Out:
# 2022-01-29 20:55:12 - MEGAHIT v1.2.9
# 2022-01-29 20:55:12 - Using megahit_core with POPCNT and BMI2 support
# 2022-01-29 20:55:12 - Convert reads to binary library
# 2022-01-29 20:58:49 - b'INFO  sequence/io/sequence_lib.cpp  :   77 - Lib 0 (/content/SRR12616406_1.fastq,/content/SRR12616406_2.fastq): pe, 32235052 reads, 150 max length'
# 2022-01-29 20:58:49 - b'INFO  utils/utils.h                 :  152 - Real: 216.9819\tuser: 30.6325\tsys: 5.9387\tmaxrss: 268884'
# 2022-01-29 20:58:49 - k-max reset to: 141
# 2022-01-29 20:58:49 - Start assembly. Number of CPU threads 2
# 2022-01-29 20:58:49 - k list: 21,29,39,59,79,99,119,141
# 2022-01-29 20:58:49 - Memory used: 12259971072
# 2022-01-29 20:58:49 - Extract solid (k+1)-mers for k = 21
# 2022-01-29 20:58:49 - b'INFO  sorting/base_engine.cpp       :  148 - Preparing data...'
# ...

# %%
# !conda install -c bioconda prokka
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - prokka
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aragorn-1.2.38             |       h516909a_3         139 KB  bioconda
#     barrnap-0.8                |                1         1.4 MB  bioconda
#     blast-2.9.0                |  pl526he19e7b1_5        19.5 MB  bioconda
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     clustalw-2.1               |       hc9558a2_5         308 KB  bioconda
#     curl-7.69.1                |       hbc83047_0         137 KB
# ...

# %%
# !conda install -c bioconda glimmer
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - glimmer
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     glimmer-3.02               |       he1b5a44_4         1.8 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         1.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   glimmer            bioconda/linux-64::glimmer-3.02-he1b5a44_4
#
#
# Proceed ([y]/n)? y
#
#
# ...
# glimmer-3.02         | 1.8 MB    | : 100% 1.0/1 [00:03<00:00,  3.32s/it]
# done
# done
# done

# %%
# !cd

# %%
# !ls
# Out:
# assemble			       sample_data  SRR12616406_1.fastq
# Miniconda3-py37_4.8.2-Linux-x86_64.sh  SRR12616406  SRR12616406_2.fastq

# %%
cd assemble
# Out:
# /content/assemble

# %%
ls
# Out:
# checkpoints.txt  final.contigs.fa       log
# done             intermediate_contigs/  options.json

# %%
# !prokka final.contigs.fa -o annotations
# Out:
# [23:04:22] This is prokka 1.13
# [23:04:22] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [23:04:22] Homepage is https://github.com/tseemann/prokka
# [23:04:22] Local time is Sat Jan 29 23:04:22 2022
# [23:04:22] You are not telling me who you are!
# [23:04:22] Operating system is linux
# [23:04:22] You have BioPerl 1.007002
# [23:04:22] System has 2 cores.
# [23:04:22] Option --cpu asked for 8 cores, but system only has 2
# [23:04:22] Will use maximum of 2 cores.
# [23:04:22] Annotating as >>> Bacteria <<<
# [23:04:22] Generating locus_tag from 'final.contigs.fa' contents.
# [23:04:22] Setting --locustag NNAOJHHH from MD5 77a83111cf60878b37c0238595b580a4
# [23:04:22] Creating new output folder: annotations
# [23:04:22] Running: mkdir -p annotations
# [23:04:22] Using filename prefix: PROKKA_01292022.XXX
# [23:04:22] Setting HMMER_NCPU=1
# [23:04:22] Writing log to: annotations/PROKKA_01292022.log
# [23:04:22] Command: /usr/local/bin/prokka final.contigs.fa -o annotations
# ...

# %%
cd annotations
# Out:
# /content/assemble/annotations

# %%
ls
# Out:
# PROKKA_01292022.err  PROKKA_01292022.fsa  PROKKA_01292022.sqn
# PROKKA_01292022.faa  PROKKA_01292022.gbk  PROKKA_01292022.tbl
# PROKKA_01292022.ffn  PROKKA_01292022.gff  PROKKA_01292022.tsv
# PROKKA_01292022.fna  PROKKA_01292022.log  PROKKA_01292022.txt

# %%
# !cat PROKKA_01292022.tsv
# Out:
# locus_tag	ftype	length_bp	gene	EC_number	COG	product
# NNAOJHHH_00001	CDS	246				hypothetical protein
# NNAOJHHH_00002	CDS	177				hypothetical protein
# NNAOJHHH_00003	CDS	822				hypothetical protein
# NNAOJHHH_00004	CDS	201				hypothetical protein
# NNAOJHHH_00005	CDS	321				hypothetical protein
# NNAOJHHH_00006	CDS	234				hypothetical protein
# NNAOJHHH_00007	CDS	315				hypothetical protein
# NNAOJHHH_00008	CDS	768	petH_1	1.18.1.2		Ferredoxin--NADP reductase
# NNAOJHHH_00009	CDS	414				hypothetical protein
# NNAOJHHH_00010	CDS	258				hypothetical protein
# NNAOJHHH_00011	CDS	411				hypothetical protein
# NNAOJHHH_00012	CDS	429				hypothetical protein
# NNAOJHHH_00013	CDS	414				hypothetical protein
# NNAOJHHH_00014	CDS	351				hypothetical protein
# NNAOJHHH_00015	CDS	837	kduI	5.3.1.17	COG3717	4-deoxy-L-threo-5-hexosulose-uronate ketol-isomerase
# NNAOJHHH_00016	CDS	762	kduD_1	1.1.1.127		2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase
# ...

# %%
cat PROKKA_01292022.tsv | cut -f3 >>gene_length.txt

# %%
cat gene_length.txt
# Out:
# length_bp
# 246
# 177
# 822
# 201
# 321
# 234
# 315
# 768
# 414
# 258
# 411
# 429
# 414
# 351
# 837
# 762
# 1668
# 891
# 921
# 1128
# 1293
# 711
# 549
# 1392
# 852
# 792
# 1167
# 1368
# 804
# 1164
# 2613
# 780
# 543
# 927
# 504
# 339
# 1197
# 519
# 1437
# 555
# 327
# 1101
# 339
# 375
# 423
# 867
# 855
# 450
# 291
# 1128
# 1287
# 876
# 834
# 771
# 474
# 573
# 1557
# 186
# 432
# 1038
# 1212
# 663
# 894
# 1158
# 834
# 813
# 1548
# 1425
# 732
# 2274
# 585
# 912
# 1896
# 582
# 828
# 426
# 633
# 1398
# 171
# 687
# 1161
# 783
# 654
# 345
# 282
# 1563
# 1092
# 1431
# 603
# 1182
# 1662
# 285
# 1047
# 1608
# 711
# 768
# 2370
# 2907
# 354
# 3495
# 1611
# 1356
# 492
# 366
# 618
# 1104
# 2220
# 2349
# 2589
# 984
# 1845
# 444
# 519
# 1512
# 561
# 987
# 744
# 621
# 834
# 2253
# 1305
# 996
# 819
# 378
# 870
# 465
# 222
# 483
# 456
# 801
# 669
# 3234
# 1176
# 822
# 744
# 324
# 1500
# 513
# 189
# 279
# 291
# 321
# 246
# 234
# 306
# 201
# 579
# 123
# 360
# 270
# 204
# 108
# 264
# 369
# 294
# 567
# 267
# ...
